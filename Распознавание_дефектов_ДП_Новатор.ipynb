# %% [markdown]
# <a href="https://colab.research.google.com/github/Shishkoder/BumpsFinder/blob/main/%D0%A0%D0%B0%D1%81%D0%BF%D0%BE%D0%B7%D0%BD%D0%B0%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D1%84%D0%B5%D0%BA%D1%82%D0%BE%D0%B2_%D0%94%D0%9F_%D0%9D%D0%BE%D0%B2%D0%B0%D1%82%D0%BE%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

from google.colab import drive
from PIL import Image
from pathlib import Path

mount_path = Path('/content/drive')
drive.mount(mount_path)
zip_file = 'drive/MyDrive/NovatorRoadsDataset.zip'
z = zipfile.ZipFile(zip_file, 'r')
z.extractall()
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.2/614.2 kB 10.5 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/pothole_dataset_v8/pothole_v8.yaml epochs=15 batch=16 name=yolov8n_v8_50e
# Out:
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/yolov8n_v8_50e2/weights/best.pt source=/content/videoplayback1.mp4 show=True imgsz=640 name=yolov8n_v8_50e2_infer640 hide_labels=True
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# video 1/1 (1/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 88.0ms
# video 1/1 (2/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 8.4ms
# video 1/1 (3/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 7.7ms
# video 1/1 (4/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 8.0ms
# video 1/1 (5/1342) /content/videoplayback1.mp4: 384x640 2 potholes, 7.6ms
# video 1/1 (6/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 8.2ms
# video 1/1 (7/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 7.5ms
# video 1/1 (8/1342) /content/videoplayback1.mp4: 384x640 1 pothole, 11.9ms
# ...
